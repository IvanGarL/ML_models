# %% [markdown]
# # Laboratorio 3 - Machine learning techniques
#  Daniel Giraldo - 201328110
#  Iván García - 201614488

# %%
#Imports
import pandas as pd
import pandas_profiling
import pickle
import numpy as np

from sklearn.svm import SVC
from collections import Counter
from pandas_profiling import ProfileReport
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelBinarizer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.base import BaseEstimator, TransformerMixin
from imblearn.over_sampling import BorderlineSMOTE
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Carga y entendimiento de datos

# %%
# Data
try:
    train = pd.read_pickle('./train.pkl')
    test = pd.read_pickle('./test.pkl')
except:
    train = pd.read_csv('https://raw.githubusercontent.com/jcestevezc/Machine-Learning-Techniques/master/Laboratorio%203/Punto%201/UNSW_NB15_training-set.csv')

    test = pd.read_csv('https://raw.githubusercontent.com/jcestevezc/Machine-Learning-Techniques/master/Laboratorio%203/Punto%201/UNSW_NB15_testing-set.csv')

    train.to_pickle('./train.pkl')
    test.to_pickle('./test.pkl')
    
train.head()
# Out:
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0   1  0.000011   udp       -   INT      2      0     496       0
# 1   2  0.000008   udp       -   INT      2      0    1762       0
# 2   3  0.000005   udp       -   INT      2      0    1068       0
# 3   4  0.000006   udp       -   INT      2      0     900       0
# 4   5  0.000010   udp       -   INT      2      0    2126       0
#
#           rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0   90909.0902  ...                 1               2             0
# 1  125000.0003  ...                 1               2             0
# 2  200000.0051  ...                 1               3             0
# 3  166666.6608  ...                 1               3             0
# 4  100000.0025  ...                 1               3             0
#
#    ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0           0                 0           1           2                0
# 1           0                 0           1           2                0
# 2           0                 0           1           3                0
# 3           0                 0           2           3                0
# 4           0                 0           2           3                0
#
#    attack_cat  label
# 0      Normal      0
# 1      Normal      0
# 2      Normal      0
# 3      Normal      0
# 4      Normal      0
#
# [5 rows x 45 columns]

# %% [markdown]
# ### Un análisis general de los datos:

# %%
#Lets start to hearing what the data have to say.

# First, compare the amount of data in 'Normal' with the not normal one, this could add some bias to the model in
#  terms of amount of data.
print("Size of all data", len(train.index))
print("Size of normal situation data", len(train.loc[train['attack_cat'] == 'Normal'].index))
print("Different kind of attacks in data", train['attack_cat'].unique(),
      "\nSize: ", len(train.loc[train['attack_cat'] != 'Normal'].index))
print("\nSize of test data: ", len(test.index))
print("Number of columns: ", len(train.columns))
# Out:
# Size of all data 82332
# Size of normal situation data 37000
# Different kind of attacks in data ['Normal' 'Reconnaissance' 'Backdoor' 'DoS' 'Exploits' 'Analysis'
#  'Fuzzers' 'Worms' 'Shellcode' 'Generic']
# Size:  45332
#
# Size of test data:  175341
# Number of columns:  45

# %% [markdown]
# ### Re-muestreo de datos
# Lo primero que intentamos hacer luego de hacer varias iteraciones de los modelos fue reducir la cardinalidad del problema, para así reducir también la complejidad. Esta decisión la basamos en el hecho de que el algoritmo que implementa la clase SVC de sklearn tiene una complejidad de O(n x m<sup>3</sup>) donde n son los numero de columnas y m el numero de muestras evaluadas en el entrenamiento.
#
# Decidimos trabajar con muestras de 6500 datos, al haber 10 clases distinas, nos parecio que tener un set de datos de 65000 muestras era lograble para el entrenamiento de los datos

# %%
#Know, for making things easier we will short the amount of data of each kind of attack
# And try to balance it, so the model could be train easyly

# We create a 6'700 sample size by each kind of data
data = {'Normal' : None, 
         'Reconnaissance' : None, 
         'Backdoor' : None, 
         'DoS' : None,
         'Exploits' : None,
         'Analysis' : None,
         'Fuzzers' : None, 
         'Worms': None, 
         'Shellcode': None, 
         'Generic': None
        }
attack_cats =  train['attack_cat'].unique()
for cat in attack_cats:
    size_data = len(train.loc[train['attack_cat'] == cat].index)
    if size_data >= 6500:
        data[cat] = train.loc[train['attack_cat'] == cat][:6500]
    else:
        data[cat] = train.loc[train['attack_cat'] == cat][:size_data]

# %% [markdown]
# ### Observaciones
# Con miras al balanceo de los datos con las técnicas estudiadas en clase de <em> oversampling </em> como son SMOT y ADASYN, miramos cuantos datos habian quedado de cada clase para poder estimar qué tipo de ténica era mejor.

# %%
# Testing good spliting
for cat in attack_cats:
    print("Size of ", cat, " categoty: ",len(data[cat].index))
# Out:
# Size of  Normal  categoty:  6500
# Size of  Reconnaissance  categoty:  3496
# Size of  Backdoor  categoty:  583
# Size of  DoS  categoty:  4089
# Size of  Exploits  categoty:  6500
# Size of  Analysis  categoty:  677
# Size of  Fuzzers  categoty:  6062
# Size of  Worms  categoty:  44
# Size of  Shellcode  categoty:  378
# Size of  Generic  categoty:  6500

# %%
# making a new data frame
train_sized = pd.DataFrame()
#train_sized = pd.concat([train_sized, data['Normal']], axis=1)
for cat in attack_cats:
    train_sized = pd.concat([train_sized, data[cat]], axis=0)
train_sized.head(10)
# Out:
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0   1  0.000011   udp       -   INT      2      0     496       0
# 1   2  0.000008   udp       -   INT      2      0    1762       0
# 2   3  0.000005   udp       -   INT      2      0    1068       0
# 3   4  0.000006   udp       -   INT      2      0     900       0
# 4   5  0.000010   udp       -   INT      2      0    2126       0
# 5   6  0.000003   udp       -   INT      2      0     784       0
# 6   7  0.000006   udp       -   INT      2      0    1960       0
# 7   8  0.000028   udp       -   INT      2      0    1384       0
# 8   9  0.000000   arp       -   INT      1      0      46       0
# 9  10  0.000000   arp       -   INT      1      0      46       0
#
#            rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0   90909.09020  ...                 1               2             0
# 1  125000.00030  ...                 1               2             0
# 2  200000.00510  ...                 1               3             0
# 3  166666.66080  ...                 1               3             0
# 4  100000.00250  ...                 1               3             0
# 5  333333.32150  ...                 1               2             0
# 6  166666.66080  ...                 1               2             0
# 7   35714.28522  ...                 1               3             0
# 8       0.00000  ...                 2               2             0
# 9       0.00000  ...                 2               2             0
#
#    ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0           0                 0           1           2                0
# 1           0                 0           1           2                0
# 2           0                 0           1           3                0
# 3           0                 0           2           3                0
# 4           0                 0           2           3                0
# 5           0                 0           2           2                0
# 6           0                 0           2           2                0
# 7           0                 0           1           3                0
# 8           0                 0           2           2                1
# 9           0                 0           2           2                1
#
#    attack_cat  label
# 0      Normal      0
# 1      Normal      0
# 2      Normal      0
# 3      Normal      0
# 4      Normal      0
# 5      Normal      0
# 6      Normal      0
# 7      Normal      0
# 8      Normal      0
# 9      Normal      0
#
# [10 rows x 45 columns]

# %%
#Check for safe concat
for col in train_sized.columns:
    print("Column ", col, " has: ", train_sized[col].isnull().sum().sum(), "NaN")
print("Total size of the data: ", len(train_sized.index))
# Out:
# Column  id  has:  0 NaN
# Column  dur  has:  0 NaN
# Column  proto  has:  0 NaN
# Column  service  has:  0 NaN
# Column  state  has:  0 NaN
# Column  spkts  has:  0 NaN
# Column  dpkts  has:  0 NaN
# Column  sbytes  has:  0 NaN
# Column  dbytes  has:  0 NaN
# Column  rate  has:  0 NaN
# Column  sttl  has:  0 NaN
# Column  dttl  has:  0 NaN
# Column  sload  has:  0 NaN
# Column  dload  has:  0 NaN
# Column  sloss  has:  0 NaN
# Column  dloss  has:  0 NaN
# Column  sinpkt  has:  0 NaN
# Column  dinpkt  has:  0 NaN
# Column  sjit  has:  0 NaN
# Column  djit  has:  0 NaN
# Column  swin  has:  0 NaN
# Column  stcpb  has:  0 NaN
# Column  dtcpb  has:  0 NaN
# Column  dwin  has:  0 NaN
# Column  tcprtt  has:  0 NaN
# Column  synack  has:  0 NaN
# Column  ackdat  has:  0 NaN
# Column  smean  has:  0 NaN
# Column  dmean  has:  0 NaN
# Column  trans_depth  has:  0 NaN
# Column  response_body_len  has:  0 NaN
# Column  ct_srv_src  has:  0 NaN
# Column  ct_state_ttl  has:  0 NaN
# Column  ct_dst_ltm  has:  0 NaN
# Column  ct_src_dport_ltm  has:  0 NaN
# Column  ct_dst_sport_ltm  has:  0 NaN
# Column  ct_dst_src_ltm  has:  0 NaN
# Column  is_ftp_login  has:  0 NaN
# Column  ct_ftp_cmd  has:  0 NaN
# Column  ct_flw_http_mthd  has:  0 NaN
# Column  ct_src_ltm  has:  0 NaN
# Column  ct_srv_dst  has:  0 NaN
# Column  is_sm_ips_ports  has:  0 NaN
# Column  attack_cat  has:  0 NaN
# Column  label  has:  0 NaN
# Total size of the data:  34829

# %% [markdown]
# ## Perfilamiento
#
# En este caso, luego de hacer el muestreo esperado de los datos, usamos el método de perfilamiento de Pandas para inspeccionar los datos y posteriormente se hizo un descarte de variables por la correlación entre estas, se encontraron las siguientes observaciones:
#
# ### Observaciones:
#
# - Habían muchos datos que tenían correlaciones entre columnas, a pesar de no tener un diccionario que nos facilitara un entendimiento más específico se podía deducir por el patrón de un sufijo **s** o **d** antes del término compartido en ambas columnas.
#
# - Basados en este [articulo](https://medium.com/@raj5287/effects-of-multi-collinearity-in-logistic-regression-svm-rf-af6766d91f1b) del blog Medium, decidimos eliminar todas las variables con una correlacion superior a 0.9 dado que estan fuertemente correlacionadas entre ellas.
#
# - Encontramos valores categoricos con alta cardinalidad lo cual afecta en 2 sentidos: la complejidad del procesamiento de los datos y el rendimiento del modelo en el sentido que va a tener que generalizar entre muchas clases distintas de atributos y eso es más difícil de modelar con un número restringido de datos

# %%
train_sized.describe()
#profile = train_sized.profile_report(title='Pandas Profiling Report')
#profile.to_file(outputfile="output_nn.html")
# Out:
#                  id           dur         spkts         dpkts        sbytes  \
# count  34829.000000  34829.000000  34829.000000  34829.000000  3.482900e+04
# mean   24920.059893      1.234828     19.586092     17.975365  9.610202e+03
# std    19591.784365      5.878477    157.562074    153.335028  2.029156e+05
# min        1.000000      0.000000      1.000000      0.000000  2.400000e+01
# 25%     8708.000000      0.000008      2.000000      0.000000  1.680000e+02
# 50%    17415.000000      0.001787      4.000000      2.000000  4.560000e+02
# 75%    45056.000000      0.640271     12.000000     10.000000  1.236000e+03
# max    65852.000000     59.997478  10646.000000  11018.000000  1.435577e+07
#
#              dbytes          rate          sttl          dttl         sload  \
# count  3.482900e+04  3.482900e+04  34829.000000  34829.000000  3.482900e+04
# mean   1.408801e+04  9.514259e+04    193.746131     87.856327  7.544815e+07
# std    2.021354e+05  1.542357e+05     95.956127    114.981627  1.830687e+08
# min    0.000000e+00  0.000000e+00      0.000000      0.000000  0.000000e+00
# 25%    0.000000e+00  3.742407e+01     62.000000      0.000000  1.418852e+04
# 50%    1.620000e+02  4.202720e+03    254.000000     29.000000  1.365619e+06
# 75%    8.240000e+02  1.250000e+05    254.000000    252.000000  9.120000e+07
# max    1.465753e+07  1.000000e+06    255.000000    253.000000  5.268000e+09
#
#        ...  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# count  ...      34829.000000      34829.000000    34829.000000  34829.000000
# mean   ...          5.810618          4.384105        8.256625      0.010824
# std    ...          9.560193          6.624989       12.577412      0.104581
# min    ...          1.000000          1.000000        1.000000      0.000000
# 25%    ...          1.000000          1.000000        1.000000      0.000000
# 50%    ...          1.000000          1.000000        2.000000      0.000000
# 75%    ...          4.000000          3.000000        7.000000      0.000000
# max    ...         59.000000         38.000000       63.000000      2.000000
#
#          ct_ftp_cmd  ct_flw_http_mthd    ct_src_ltm    ct_srv_dst  \
# count  34829.000000      34829.000000  34829.000000  34829.000000
# mean       0.010882          0.112090      7.497459      9.941198
# std        0.105395          0.491877      9.559064     12.194247
# min        0.000000          0.000000      1.000000      1.000000
# 25%        0.000000          0.000000      1.000000      1.000000
# 50%        0.000000          0.000000      3.000000      5.000000
# 75%        0.000000          0.000000     10.000000     12.000000
# max        2.000000         16.000000     60.000000     62.000000
#
#        is_sm_ips_ports         label
# count     34829.000000  34829.000000
# mean          0.000574      0.813374
# std           0.023957      0.389617
# min           0.000000      0.000000
# 25%           0.000000      1.000000
# 50%           0.000000      1.000000
# 75%           0.000000      1.000000
# max           1.000000      1.000000
#
# [8 rows x 41 columns]

# %%
#Profile report
#train_sized.profile_report()

# %%
#Look for correlations in fields
corr = train_sized.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col2 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col3 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col4 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col5 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col6 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col7 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col8 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col9 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col10 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col11 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col12 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col13 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col14 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col15 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col16 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col17 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col18 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col19 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col20 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col21 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col22 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col23 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col24 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col25 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col26 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col27 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col28 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col29 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col30 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col31 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col32 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col33 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col34 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col35 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col36 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col37 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col38 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col39 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row0_col40 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col0 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col2 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col3 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col4 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col5 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col6 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col7 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col8 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col9 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col10 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col11 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col12 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col13 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col14 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col15 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col16 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col17 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_928694a2_c1c5_11ea_a060_96339f695b93row1_col18 {
#             background-color:  #

# %% [markdown]
# ## Selección de variables
#
# Basados en los resultados de la matriz de autocorrelación, escogimos las variables a descartar y establecimos los set de datos de prueba y de entrenamiento.

# %%
discard_vals = ["id", "spkts", "sbytes", "dpkts", "dbytes", "dload", "dloss", "sinpkt", "dinpkt", "djit",
                "sjit", "tcprtt", "synack", "dwin", "ackdat", "trans_depth", "is_ftp_login", "dmean",
                "response_body_len", "ct_flw_http_mthd", "ct_dst_ltm","attack_cat", "ct_src_dport_ltm", "ct_dst_src_ltm",
                "ct_srv_src"]

X_train = train_sized.drop(discard_vals, axis=1)
y_train = train_sized['attack_cat']

X_test = test.drop(discard_vals, axis=1)
y_test = test['attack_cat']

corr = X_train.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col1 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col2 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col3 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col4 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col5 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col6 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col7 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col8 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col9 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col10 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col11 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col12 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col13 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col14 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col15 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row0_col16 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col2 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col4 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col6 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col7 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col8 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col9 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col10 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col11 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col12 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col13 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col14 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col15 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row1_col16 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col0 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col1 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col3 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col4 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col6 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col7 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col8 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col9 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col10 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col11 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col13 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col14 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row2_col16 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row3_col0 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row3_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row3_col2 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row3_col4 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row3_col5 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row3_col6 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row3_col7 {
#             background-color:  #f39577;
#             color:  #000000;
#         }    #T_3f1c0f30_c23f_11ea_889d_96339f695b93row3_col8 {
#             background-color:  #f39577;

# %% [markdown]
# ### Limpieza de datos.
# En el proceso de limpieza de datos llevamos acabo los siguientes procesos:
#
# - Disminución de la cardinalidad de los datos categoricos.
# - Codificación de las variables categoricas de los datos usando la técnica OneHotEncoding explicada en el libro referencia de la materia.
# - Balanceo de los datos para un entrenamiento mucho más efectivo

# %%
#There is a problem with 'proto' variable: high cardinality, we are going to try to fix it.

protos = X_train['proto'].unique()
n_protos = []
for proto in protos:
    size = len(X_train.loc[X_train['proto'] == proto].index)
    if size < 100:
        n_protos.append(proto)

for not_include in n_protos:
    X_train.loc[X_train['proto'] == not_include, 'proto'] = 'otros'
    X_test.loc[X_test['proto'] == not_include, 'proto'] = 'otros'

# %%
"""
One-hot encode categorical data
"""

class CategoricalTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
        self.encoders = []
    
    def fit(self, X, y=None):
        for col in self.columns:
            lb = LabelBinarizer()
            lb = lb.fit(X[col])
            self.encoders.append(lb)
        return self
    def transform(self, X, y=None):
        for i, col in enumerate(self.columns):
            enc = self.encoders[i].transform(X[col])
            enc_df = pd.DataFrame(enc, columns=self.encoders[i].classes_, index=X.index)
            enc_df = enc_df.add_prefix('{}_'.format(col))
            X = X.join(enc_df)
            X = X.drop(col, axis=1)
        return X

CT = CategoricalTransformer(['state',
                             'proto',
                             'service'])
CT_test = CT.fit_transform(X_train)
print(CT_test.columns)
# Out:
# Index(['dur', 'rate', 'sttl', 'dttl', 'sload', 'sloss', 'swin', 'stcpb',
#        'dtcpb', 'smean', 'ct_state_ttl', 'ct_dst_sport_ltm', 'ct_ftp_cmd',
#        'ct_src_ltm', 'ct_srv_dst', 'is_sm_ips_ports', 'label', 'state_ACC',
#        'state_CLO', 'state_CON', 'state_FIN', 'state_INT', 'state_REQ',
#        'state_RST', 'proto_ospf', 'proto_otros', 'proto_sctp', 'proto_tcp',
#        'proto_udp', 'proto_unas', 'service_-', 'service_dhcp', 'service_dns',
#        'service_ftp', 'service_ftp-data', 'service_http', 'service_irc',
#        'service_pop3', 'service_radius', 'service_smtp', 'service_snmp',
#        'service_ssh', 'service_ssl'],
#       dtype='object')

# %% [markdown]
# ## Modelamiento
#
# - Para este problema en particular se decidió usar un balanceador SMOTE, con su variante de Borderline, el cual define una replica sintética en un vector borde entre dos ejemplares cercanos definidos por una función de distancia. Según lo investigado, se puede ver en esta [guía de usuario] que BorderLineSMOTE parece ser el balanceador que menos <em>overlaping</em> genera, por dicha razón lo escogimos.
#
# - En cuanto al kernel para la máquina de soporte vectorial, escogimos el kernel gaussiano <em>RBF</em> ya que acorde con lo consultado en el libro guía de la materia es uno de los que mejor rendimiento tiene. Además, al no saber si es un problema linearmente separable, nos parecio adecuado descartar el kernel lineal a pesar de que LinearSVC tuviera un rendimiento mucho mejor que SVC

# %%
pipe = Pipeline([
    ('encoding', CategoricalTransformer(['state',
                             'proto',
                             'service'])),
    ('standarize', StandardScaler())
])

X_prepared_data_train = pipe.fit_transform(X_train)
sm = BorderlineSMOTE(random_state=42, n_jobs=5)
print('Original dataset shape %s' % Counter(y_train))
X_balanced_train, y_balanced_train = sm.fit_resample(X_prepared_data, y_train)
print('Balanced dataset shape %s' % Counter(y_balanced_train))
# Out:
# Original dataset shape Counter({'Normal': 6500, 'Exploits': 6500, 'Generic': 6500, 'Fuzzers': 6062, 'DoS': 4089, 'Reconnaissance': 3496, 'Analysis': 677, 'Backdoor': 583, 'Shellcode': 378, 'Worms': 44})
# Balanced dataset shape Counter({'Normal': 6500, 'Reconnaissance': 6500, 'Backdoor': 6500, 'DoS': 6500, 'Exploits': 6500, 'Analysis': 6500, 'Fuzzers': 6500, 'Worms': 6500, 'Shellcode': 6500, 'Generic': 6500})

# %%
param_grid = { 'C': [12.5, 6.0, 3.0, 0.5], 
               'gamma': [0.1, 0.5, 2.5, 5] }

gm = SVC(kernel="rbf")

model = GridSearchCV(gm, param_grid=param_grid, cv=5, n_jobs=5, verbose=20).best_estimator_
model.fit(X_balanced_train, y_balanced_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   1 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=5)]: Done   2 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=5)]: Done   3 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=5)]: Done   4 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=5)]: Done   5 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=5)]: Done   6 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=5)]: Done   7 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=5)]: Done   8 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=5)]: Done   9 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=5)]: Done  10 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=5)]: Done  11 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=5)]: Done  12 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=5)]: Done  13 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=5)]: Done  14 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=5)]: Done  15 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=5)]: Done  16 tasks      | elapsed: 20.3min
# [Parallel(n_jobs=5)]: Done  17 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=5)]: Done  18 tasks      | elapsed: 20.6min
# [Parallel(n_jobs=5)]: Done  19 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=5)]: Done  20 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=5)]: Done  21 tasks      | elapsed: 24.1min
# [Parallel(n_jobs=5)]: Done  22 tasks      | elapsed: 24.5min
# [Parallel(n_jobs=5)]: Done  23 tasks      | elapsed: 24.5min
# [Parallel(n_jobs=5)]: Done  24 tasks      | elapsed: 24.7min
# [Parallel(n_jobs=5)]: Done  25 tasks      | elapsed: 24.8min
# [Parallel(n_jobs=5)]: Done  26 tasks      | elapsed: 28.1min
# [Parallel(n_jobs=5)]: Done  27 tasks      | elapsed: 28.6min
# [Parallel(n_jobs=5)]: Done  28 tasks      | elapsed: 28.7min
# [Parallel(n_jobs=5)]: Done  29 tasks      | elapsed: 28.8min
# [Parallel(n_jobs=5)]: Done  30 tasks      | elapsed: 28.9min
# [Parallel(n_jobs=5)]: Done  31 tasks      | elapsed: 33.2min
# [Parallel(n_jobs=5)]: Done  32 tasks      | elapsed: 33.9min
# [Parallel(n_jobs=5)]: Done  33 tasks      | elapsed: 34.0min
# [Parallel(n_jobs=5)]: Done  34 tasks      | elapsed: 34.0min
# [Parallel(n_jobs=5)]: Done  35 tasks      | elapsed: 34.1min
# [Parallel(n_jobs=5)]: Done  36 tasks      | elapsed: 39.4min
# [Parallel(n_jobs=5)]: Done  37 tasks      | elapsed: 40.2min
# [Parallel(n_jobs=5)]: Done  38 tasks      | elapsed: 40.3min
# [Parallel(n_jobs=5)]: Done  39 tasks      | elapsed: 40.5min
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed: 40.5min
# [Parallel(n_jobs=5)]: Done  41 tasks      | elapsed: 43.1min
# [Parallel(n_jobs=5)]: Done  42 tasks      | elapsed: 44.0min
# [Parallel(n_jobs=5)]: Done  43 tasks      | elapsed: 44.1min
# [Parallel(n_jobs=5)]: Done  44 tasks      | elapsed: 44.2min
# [Parallel(n_jobs=5)]: Done  45 tasks      | elapsed: 44.3min
# [Parallel(n_jobs=5)]: Done  46 tasks      | elapsed: 46.9min
# [Parallel(n_jobs=5)]: Done  47 tasks      | elapsed: 48.1min
# [Parallel(n_jobs=5)]: Done  48 tasks      | elapsed: 48.1min
# [Parallel(n_jobs=5)]: Done  49 tasks      | elapsed: 48.2min
# [Parallel(n_jobs=5)]: Done  50 tasks      | elapsed: 48.3min
# [Parallel(n_jobs=5)]: Done  51 tasks      | elapsed: 51.9min
# [Parallel(n_jobs=5)]: Done  52 tasks      | elapsed: 53.2min
# [Parallel(n_jobs=5)]: Done  53 tasks      | elapsed: 53.3min
# [Parallel(n_jobs=5)]: Done  54 tasks      | elapsed: 53.4min
# [Parallel(n_jobs=5)]: Done  55 tasks      | elapsed: 53.4min
# [Parallel(n_jobs=5)]: Done  56 tasks      | elapsed: 58.2min
# [Parallel(n_jobs=5)]: Done  57 tasks      | elapsed: 59.7min
# [Parallel(n_jobs=5)]: Done  58 tasks      | elapsed: 59.8min
# [Parallel(n_jobs=5)]: Done  59 tasks      | elapsed: 59.9min
# [Parallel(n_jobs=5)]: Done  60 tasks      | elapsed: 59.9min
# [Parallel(n_jobs=5)]: Done  61 tasks      | elapsed: 62.3min
# [Parallel(n_jobs=5)]: Done  62 tasks      | elapsed: 64.0min
# [Parallel(n_jobs=5)]: Done  63 tasks      | elapsed: 64.0min
# [Parallel(n_jobs=5)]: Done  64 tasks      | elapsed: 64.1min
# [Parallel(n_jobs=5)]: Done  65 tasks      | elapsed: 64.1min
# [Parallel(n_jobs=5)]: Done  66 tasks      | elapsed: 66.5min
# [Parallel(n_jobs=5)]: Done  67 tasks      | elapsed: 68.2min
# [Parallel(n_jobs=5)]: Done  68 tasks      | elapsed: 68.3min
# [Parallel(n_jobs=5)]: Done  69 tasks      | elapsed: 68.4min
# [Parallel(n_jobs=5)]: Done  70 tasks      | elapsed: 68.4min
# [Parallel(n_jobs=5)]: Done  71 tasks      | elapsed: 71.7min
# [Parallel(n_jobs=5)]: Done  76 out of  80 | elapsed: 78.2min remaining:  4.1min
# [Parallel(n_jobs=5)]: Done  80 out of  80 | elapsed: 80.4min finished
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=5,
#              param_grid={'C': [12.5, 6.0, 3.0, 0.5],
#                          'gamma': [0.1, 0.5, 2.5, 5]},
#              verbose=20)

# %% [markdown]
# ## Resultados
# Después de entrenarse el modelo con una variacion definida de los parámetros C y gamma se obtuvieron los resultados a contiinuación expuestos.
#
# Cabe aclarar que debido a la falta de tiempo no se pudieron realizar más iteraciones sobre el modelo diseñado y como puede ver la duración de su entrenamiento duró cerca de 80 minutos reducida en gran tamaño de complejidad. Acerca de los resultados se pueden generar las siguientes conclusiones:
#
# 1. El modelo tiene un rendimiento óptimo para los datos de prueba usados. No obstante, su rendimiento para los datos de prueba no supera el 60% en promedio para el tamaño de datos usado (170 mil), de esto se puede inferir que el modelo está cayendo en un patrón de sobreajuste, por lo que la varianza del problema está siendo muy alta.
#
# 2. Al reconocer el parámetro de sobreajuste, se podría buscar implementar algunas técnicas de regularización para disminuir la complejidad del modelo, como cambiar a un kernel polinomico de grado 3 o 2 o buscar mejores insights de los datos con un modelo regresivo logístico previo a la SVM.
#
# 3. Se podría buscar también aumentar la cantidad de datos del set de entrenamiento, subir la cantidad a 8 mil o 10 mil datos por clase ayudaría a mejorar los errores por sesgo que también pueda estar teniendo el modelo.

# %%
"""
Hyperparameters Results
"""
results = model.cv_results_
resultsSorted = sorted(zip(results["mean_test_score"], results["params"]), key=lambda pair: -pair[0])

print('Best hyperparameters: \n')
for mean_score, params in resultsSorted:
    print('mean accuracy: ', mean_score, 'params: ', params)
# Out:
# Best hyperparameters:
#
# mean accuracy:  0.7182923076923078 params:  {'C': 12.5, 'gamma': 5}
# mean accuracy:  0.7161846153846154 params:  {'C': 6.0, 'gamma': 5}
# mean accuracy:  0.7154769230769231 params:  {'C': 12.5, 'gamma': 2.5}
# mean accuracy:  0.7113230769230768 params:  {'C': 6.0, 'gamma': 2.5}
# mean accuracy:  0.7112153846153847 params:  {'C': 3.0, 'gamma': 5}
# mean accuracy:  0.7044461538461538 params:  {'C': 3.0, 'gamma': 2.5}
# mean accuracy:  0.6910000000000001 params:  {'C': 12.5, 'gamma': 0.5}
# mean accuracy:  0.6847538461538462 params:  {'C': 0.5, 'gamma': 5}
# mean accuracy:  0.6836769230769232 params:  {'C': 6.0, 'gamma': 0.5}
# mean accuracy:  0.6783384615384616 params:  {'C': 12.5, 'gamma': 0.1}
# mean accuracy:  0.6768 params:  {'C': 3.0, 'gamma': 0.5}
# mean accuracy:  0.675523076923077 params:  {'C': 0.5, 'gamma': 2.5}
# mean accuracy:  0.6731076923076923 params:  {'C': 6.0, 'gamma': 0.1}
# mean accuracy:  0.665 params:  {'C': 3.0, 'gamma': 0.1}
# mean accuracy:  0.6643230769230769 params:  {'C': 0.5, 'gamma': 0.5}
# mean accuracy:  0.6353538461538462 params:  {'C': 0.5, 'gamma': 0.1}

# %%
"""
Validation
"""
#predictions = model.predict(X_test)
train_predictions = model.predict(X_balanced_train)
print('__ Train Scores __\n')
print(classification_report(y_balanced_train, train_predictions))
# Out:
# __ Train Scores __
#
#                 precision    recall  f1-score   support
#
#       Analysis       0.51      0.59      0.54      6500
#       Backdoor       0.49      0.58      0.53      6500
#            DoS       0.56      0.73      0.63      6500
#       Exploits       0.91      0.61      0.73      6500
#        Fuzzers       0.97      0.74      0.84      6500
#        Generic       1.00      1.00      1.00      6500
#         Normal       1.00      1.00      1.00      6500
# Reconnaissance       0.88      0.81      0.84      6500
#      Shellcode       0.96      0.97      0.97      6500
#          Worms       1.00      1.00      1.00      6500
#
#       accuracy                           0.80     65000
#      macro avg       0.83      0.80      0.81     65000
#   weighted avg       0.83      0.80      0.81     65000
#
# __ Test Scores __

# %%
# Testing process
X_prepared_data_test = pipe.fit_transform(X_test)
print(CT_test.columns)
predictions = model.predict(X_prepared_data_test)
# Out:
# Index(['dur', 'rate', 'sttl', 'dttl', 'sload', 'sloss', 'swin', 'stcpb',
#        'dtcpb', 'smean', 'ct_state_ttl', 'ct_dst_sport_ltm', 'ct_ftp_cmd',
#        'ct_src_ltm', 'ct_srv_dst', 'is_sm_ips_ports', 'label', 'state_ACC',
#        'state_CLO', 'state_CON', 'state_FIN', 'state_INT', 'state_REQ',
#        'state_RST', 'proto_ospf', 'proto_otros', 'proto_sctp', 'proto_tcp',
#        'proto_udp', 'proto_unas', 'service_-', 'service_dhcp', 'service_dns',
#        'service_ftp', 'service_ftp-data', 'service_http', 'service_irc',
#        'service_pop3', 'service_radius', 'service_smtp', 'service_snmp',
#        'service_ssh', 'service_ssl'],
#       dtype='object')
# __ Test Scores __
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-ac02d364d74e> in <module>
#       4 predictions = model.predict(X_prepared_data_test)
#       5 print('__ Test Scores __\n')
# ----> 6 print(classification_report(y_test, predictions, average='weighted', labels= np.unique(predictions)))
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# TypeError: classification_report() got an unexpected keyword argument 'average'

# %%
print('__ Test Scores __\n')
print(classification_report(y_test, predictions, labels= np.unique(predictions)))
# Out:
# __ Test Scores __
#
#                 precision    recall  f1-score   support
#
#       Analysis       0.05      0.00      0.00      2000
#       Backdoor       0.05      0.01      0.02      1746
#            DoS       0.29      0.34      0.31     12264
#       Exploits       0.22      0.71      0.33     33393
#        Fuzzers       0.75      0.63      0.68     18184
#        Generic       1.00      0.67      0.80     40000
# Reconnaissance       0.73      0.61      0.67     10491
#      Shellcode       0.42      0.29      0.35      1133
#          Worms       0.00      0.00      0.00       130
#
#      micro avg       0.42      0.61      0.49    119341
#      macro avg       0.39      0.36      0.35    119341
#   weighted avg       0.61      0.61      0.56    119341
